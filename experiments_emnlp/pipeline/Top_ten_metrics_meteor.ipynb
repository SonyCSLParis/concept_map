# %%
import os
import json
import numpy as np
import regex as re
import matplotlib.pyplot as plt

class MetricsPlotter:
    def __init__(self, root_dir):
        self.root_dir = root_dir
        self.metrics_data = [] 
        self.top_10_precision = {}
        self.top_10_recall = {}
        self.top_10_f1 = {}

    def read_json(self, file_path):
        with open(file_path, 'r') as file:
            return json.load(file)
            
    def sanitize_filename(self, filename):
        filename = filename.replace(' ', '_')
        filename = re.sub(r'[^\w\-_\.]', '', filename)
        return filename
        
    def get_params_string(self, params):
        summary = params.get('summary', {})
        ranking = params.get('ranking', {})
        entity = params.get('entity', {})
        relation = params.get('relation', {})

        preprocess_str = f"Preprocess: {params.get('preprocess', None)}" if params.get('preprocess', None) is not None else ''
        summary_method = f"Summary Method: {summary.get('summary_method', None)}" if summary.get('summary_method', None) is not None else ''
        summary_percentage = f"Summary Percentage: {summary.get('summary_percentage', None)}" if summary.get('summary_percentage', None) is not None else ''
        ranking_method = f"Ranking Method: {ranking.get('ranking', None)}" if ranking.get('ranking', None) is not None else ''
        ranking_perc_threshold = f"Ranking Perc Threshold: {ranking.get('ranking_perc_threshold', None)}" if ranking.get('ranking_perc_threshold', None) is not None else ''
        options_ent = f"Options Ent: {', '.join(sorted(entity.get('options_ent', [None])))}" if sorted(entity.get('options_ent', [None])) != [None] else ''
        options_rel = f"Options Rel: {', '.join(sorted(relation.get('options_rel', [None])))}" if sorted(relation.get('options_rel', [None])) != [None] else ''
        local_rm = f"Local RM: {relation.get('local_rm', None)}" if relation.get('local_rm', None) is not None else ''
        rebel_model = f"Rebel Model: {relation.get('rebel_model', None)}" if relation.get('rebel_model', None) is not None else ''
        
        params_list = [preprocess_str, summary_method, summary_percentage, ranking_method, ranking_perc_threshold, options_ent, options_rel, local_rm, rebel_model]
        params_str = '\n'.join(filter(None, params_list))

        return params_str

    def compute_average_meteor_scores(self, json_data):
        meteor_precision_scores = []
        meteor_recall_scores = []
        meteor_f1_scores = []
        for v in json_data.values():
            if 'meteor' in v:
                meteor_scores = v['meteor']
                if 'precision' in meteor_scores and 'recall' in meteor_scores and 'f1' in meteor_scores:
                    meteor_precision_scores.append(meteor_scores['precision'])
                    meteor_recall_scores.append(meteor_scores['recall'])
                    meteor_f1_scores.append(meteor_scores['f1'])
                else:
                    print("Warning: Missing Meteor scores in JSON data.")
            else:
                print("Warning: Missing Meteor scores in JSON data.")
        avg_precision = np.mean(meteor_precision_scores)
        avg_recall = np.mean(meteor_recall_scores)
        avg_f1 = np.mean(meteor_f1_scores)
        return avg_precision, avg_recall, avg_f1
        
    def print_metrics(self, json_file, params_str):
        with open(json_file) as f:
            data = json.load(f)
        avg_precision, avg_recall, avg_f1 = self.compute_average_meteor_scores(data)
        self.metrics_data.append({
            "Params": params_str,
            "Avg Meteor Precision": avg_precision,
            "Avg Meteor Recall": avg_recall,
            "Avg Meteor F1": avg_f1
        })
        # Debugging statement to check the structure
        print(f"Appended metrics: {self.metrics_data[-1]}")

    def plot_metrics_bar_directory(self):
        for root, dirs, _ in os.walk(self.root_dir):
            for dir_name in dirs:
                metrics_path = os.path.join(root, dir_name, 'metrics.json')
                params_path = os.path.join(root, dir_name, 'params.json')
    
                if all(os.path.exists(p) for p in [metrics_path, params_path]):
                    try:
                        params = self.read_json(params_path)
                        params_str = self.get_params_string(params)
                        self.print_metrics(metrics_path, params_str)  # Uncommented this line
                    except Exception as e:
                        print(f"Error processing files in directory: {os.path.join(root, dir_name)}")
                        print(e) 

    def print_metrics_data(self):
            for params, metrics in self.metrics_data.items():
                print(f"Params: {params}")
                print(f"Metrics: {metrics}")

    def sort_and_store_top_metrics(self):
        sorted_by_precision = sorted(self.metrics_data, key=lambda x: x["Avg Meteor Precision"], reverse=True)[:10]
        print(f"Top 10 by Precision: {sorted_by_precision}")
        sorted_by_recall = sorted(self.metrics_data, key=lambda x: x["Avg Meteor Recall"], reverse=True)[:10]
        print(f"Top 10 by Recall: {sorted_by_recall}")
        sorted_by_f1 = sorted(self.metrics_data, key=lambda x: x["Avg Meteor F1"], reverse=True)[:10]
        print(f"Top 10 by F1: {sorted_by_f1}")

        self.top_10_precision = {item["Params"]: item["Avg Meteor Precision"] for item in sorted_by_precision}
        self.top_10_recall = {item["Params"]: item["Avg Meteor Recall"] for item in sorted_by_recall}
        self.top_10_f1 = {item["Params"]: item["Avg Meteor F1"] for item in sorted_by_f1}

    def print_top_metrics(self):
        print("Top 10 Avg Meteor Precision:")
        for params, value in self.top_10_precision.items():
            print(f"Params: {params}\nPrecision: {value}\n")
        
        print("Top 10 Avg Meteor Recall:")
        for params, value in self.top_10_recall.items():
            print(f"Params: {params}\nRecall: {value}\n")
        
        print("Top 10 Avg Meteor F1:")
        for params, value in self.top_10_f1.items():
            print(f"Params: {params}\nF1: {value}\n")

    def plot_top_metrics(self):
        fig_dir = 'plot/plot_metrics/meteor/top_10_meteor'
        if not os.path.exists(fig_dir):
            os.makedirs(fig_dir)
        def plot_metric(metric_dict, title, ylabel):
            params = list(metric_dict.keys())
            values = list(metric_dict.values())
            plt.figure(figsize=(20, 10))
            plt.bar(params, values, color='skyblue')
            plt.xlabel(ylabel)
            plt.ylabel("Score")
            plt.title(title)
            plt.grid(axis='y', linestyle='--', alpha=0.4)
            plt.xticks(rotation=45, ha='right')  # Adjust rotation angle and alignment
            plt.tight_layout()
            fig_path = os.path.join(fig_dir, f"{title}_plot.png")
            plt.savefig(fig_path)
            plt.show()
            plt.close()

        plot_metric(self.top_10_f1, "Top 10 Avg Meteor F1 Scores", "F1 Score")
        plot_metric(self.top_10_precision, "Top 10 Avg Meteor Precision Scores", "Precision Score")
        plot_metric(self.top_10_recall, "Top 10 Avg Meteor Recall Scores", "Recall Score")

# %%
root_directory = "/Users/martina/Desktop/concept_map/experiments"
plotter = MetricsPlotter(root_directory)
plotter.plot_metrics_bar_directory()
plotter.sort_and_store_top_metrics()
plotter.print_top_metrics()
# Out:
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 26.433528072405245, 'Avg Meteor Recall': 23.122093039454054, 'Avg Meteor F1': 24.303592811145137}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 30.921189871034464, 'Avg Meteor Recall': 20.19425657245611, 'Avg Meteor F1': 23.952769311898575}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision':

# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 32.64062843570239, 'Avg Meteor Recall': 21.952115428353423, 'Avg Meteor F1': 25.778057668696604}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 32.5824522454331, 'Avg Meteor Recall': 17.361217470155875, 'Avg Meteor F1': 22.16084061363668}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 30.727909437834256, 'Avg Meteor Recall': 20.809234527902078, 'Avg Meteor F1': 24.047331426560373}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 38.31075627375849, 'Avg Meteor Recall': 18.217830658040818, 'Avg Meteor F1': 24.19426051791469}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 28.43014216296447, 'Avg Meteor Recall': 22.097105504601565, 'Avg Meteor F1': 24.171103769030278}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nOptions Rel: corenlp", 'Avg Meteor Precision': 36.553182202249985, 'Avg Meteor Recall': 24.317201723566995, 'Avg Meteor F1': 28.567748532576317}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 12.974272512178, 'Avg Meteor Recall': 14.238660167476286, 'Avg Meteor F1': 12.482948542404099}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nOptions Rel: corenlp", 'Avg Meteor Precision': 29.76033842836111, 'Avg Meteor Recall': 14.990518660843643, 'Avg Meteor F1': 19.643131365488173}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 30.494548225242553, 'Avg Meteor Recall': 26.19309113447543, 'Avg Meteor F1': 27.396511168048566}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 27.39442304073948, 'Avg Meteor Recall': 22.93081523407605, 'Avg Meteor F1': 23.9570791030786}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 38.70915468350132, 'Avg Meteor Recall': 18.010695781779233, 'Avg Meteor F1': 23.983606585795233}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 23.871044546328502, 'Avg Meteor Recall': 27.876672224749566, 'Avg Meteor F1': 25.148858115682845}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 13.300780155537268, 'Avg Meteor Recall': 21.57988384334356, 'Avg Meteor F1': 15.862109798688108}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 31.58296475097177, 'Avg Meteor Recall': 26.687310902019398, 'Avg Meteor F1': 28.335923876355835}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 26.07724882860422, 'Avg Meteor Recall': 24.803446561258728, 'Avg Meteor F1': 24.836715305095687}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 31.40225241258758, 'Avg Meteor Recall': 23.136667890558506, 'Avg Meteor F1': 25.99113383820286}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 29.10605690342812, 'Avg Meteor Recall': 34.50135528761688, 'Avg Meteor F1': 30.133427099784356}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 24.167226819207503, 'Avg Meteor Recall': 24.276124108633795, 'Avg Meteor F1': 23.63124238795393}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 20.689224561732043, 'Avg Meteor Recall': 17.577856542550887, 'Avg Meteor F1': 17.79593066297514}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 35.929279403348204, 'Avg Meteor Recall': 22.321750520734582, 'Avg Meteor F1': 26.861405538379685}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 36.25391790430716, 'Avg Meteor Recall': 18.38890458714981, 'Avg Meteor F1': 23.85374998670368}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 29.99542908497471, 'Avg Meteor Recall': 27.09035100953002, 'Avg Meteor F1': 27.53687242118027}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nOptions Rel: corenlp", 'Avg Meteor Precision': 34.428875275993775, 'Avg Meteor Recall': 26.038735917738688, 'Avg Meteor F1': 29.1109748024941}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 17.67687965751143, 'Avg Meteor Recall': 21.765905019329725, 'Avg Meteor F1': 18.881728545339342}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 33.05240230087606, 'Avg Meteor Recall': 18.131208610889367, 'Avg Meteor F1': 22.9211247244871}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 12.945355143706426, 'Avg Meteor Recall': 21.22460683234443, 'Avg Meteor F1': 14.853652889493858}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 14.561166468044712, 'Avg Meteor Recall': 20.609711383158174, 'Avg Meteor F1': 16.701155549076567}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 36.89438041088255, 'Avg Meteor Recall': 19.912631826974337, 'Avg Meteor F1': 25.517873404194507}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 32.733424619953865, 'Avg Meteor Recall': 30.310427790971186, 'Avg Meteor F1': 30.671572676698773}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 14.802977838335735, 'Avg Meteor Recall': 16.67917164090312, 'Avg Meteor F1': 14.696643594755411}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 35.314525774811386, 'Avg Meteor Recall': 20.427820279325346, 'Avg Meteor F1': 25.371431872318283}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 25.308366541044794, 'Avg Meteor Recall': 22.20475766581317, 'Avg Meteor F1': 22.933381457767542}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 33.469658665475016, 'Avg Meteor Recall': 20.88030613347601, 'Avg Meteor F1': 25.216600489467414}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 30.742545376488543, 'Avg Meteor Recall': 21.02367439718132, 'Avg Meteor F1': 24.52230802033916}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 27.84394990471177, 'Avg Meteor Recall': 28.514786870769992, 'Avg Meteor F1': 27.3755511119415}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 34.216769601659855, 'Avg Meteor Recall': 17.587355344091254, 'Avg Meteor F1': 22.8106773085901}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 22.795303836519967, 'Avg Meteor Recall': 24.510685655266577, 'Avg Meteor F1': 23.164556769992323}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 24.310502561170292, 'Avg Meteor Recall': 22.839838875396758, 'Avg Meteor F1': 22.759970666051842}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 21.062379192780014, 'Avg Meteor Recall': 22.957516343006724, 'Avg Meteor F1': 21.282332131627015}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 26.932875791678654, 'Avg Meteor Recall': 25.29634672914829, 'Avg Meteor F1': 25.34760561236784}
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 23.603643546757457, 'Avg Meteor Recall': 15.469162302911357, 'Avg Meteor F1': 18.146994797353454}
# ...
# Appended metrics: {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 15\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 15.889513990171684, 'Avg Meteor Recall': 18.934997464407758, 'Avg Meteor F1': 15.62616581199218}
# Top 10 by Precision: [{'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 45.42353180715182, 'Avg Meteor Recall': 15.841912463854326, 'Avg Meteor F1': 23.329047432058545}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nOptions Rel: corenlp", 'Avg Meteor Precision': 44.64432639602166, 'Avg Meteor Recall': 15.6580268944039, 'Avg Meteor F1': 22.94183351474825}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 44.58219759158727, 'Avg Meteor Recall': 14.2565793057341, 'Avg Meteor F1': 21.327163812942217}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 44.27574684680341, 'Avg Meteor Recall': 20.643638021597447, 'Avg Meteor F1': 27.642359310745967}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nOptions Rel: corenlp", 'Avg Meteor Precision': 44.00871387265893, 'Avg Meteor Recall': 20.92481679003488, 'Avg Meteor F1': 27.78972658652946}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 43.65769014094927, 'Avg Meteor Recall': 18.918071092961007, 'Avg Meteor F1': 25.667661983203203}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 39.537773093892916, 'Avg Meteor Recall': 18.795910286012433, 'Avg Meteor F1': 25.04619089438602}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 38.98260935237256, 'Avg Meteor Recall': 18.862667813795372, 'Avg Meteor F1': 25.08574587000456}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 38.93965267196027, 'Avg Meteor Recall': 20.032102327084175, 'Avg Meteor F1': 26.09417997738415}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 38.70915468350132, 'Avg Meteor Recall': 18.010695781779233, 'Avg Meteor F1': 23.983606585795233}]
# Top 10 by Recall: [{'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 29.10605690342812, 'Avg Meteor Recall': 34.50135528761688, 'Avg Meteor F1': 30.133427099784356}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 22.492678677279567, 'Avg Meteor Recall': 31.050638651634646, 'Avg Meteor F1': 25.407603244525912}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 22.068865339298203, 'Avg Meteor Recall': 31.000162336682557, 'Avg Meteor F1': 24.56018441650749}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 30.200616211928665, 'Avg Meteor Recall': 30.989374006799213, 'Avg Meteor F1': 29.37900293325788}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 22.437873133738695, 'Avg Meteor Recall': 30.875366506026484, 'Avg Meteor F1': 24.85530036514726}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 30.434291616319655, 'Avg Meteor Recall': 30.340468363524383, 'Avg Meteor F1': 29.640729305577235}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 32.733424619953865, 'Avg Meteor Recall': 30.310427790971186, 'Avg Meteor F1': 30.671572676698773}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 26.347860392290624, 'Avg Meteor Recall': 28.78794499253745, 'Avg Meteor F1': 26.774310557590052}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: True\nRebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth", 'Avg Meteor Precision': 21.02804636213018, 'Avg Meteor Recall': 28.719132894017253, 'Avg Meteor F1': 23.591024625055155}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: page_rank\nRanking Perc Threshold: 0.15\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 25.35812019844619, 'Avg Meteor Recall': 28.551810280783368, 'Avg Meteor F1': 25.812830417360832}]
# Top 10 by F1: [{'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 32.733424619953865, 'Avg Meteor Recall': 30.310427790971186, 'Avg Meteor F1': 30.671572676698773}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.15\nOptions Rel: corenlp", 'Avg Meteor Precision': 29.10605690342812, 'Avg Meteor Recall': 34.50135528761688, 'Avg Meteor F1': 30.133427099784356}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 30.434291616319655, 'Avg Meteor Recall': 30.340468363524383, 'Avg Meteor F1': 29.640729305577235}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 30.200616211928665, 'Avg Meteor Recall': 30.989374006799213, 'Avg Meteor F1': 29.37900293325788}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 15\nOptions Rel: corenlp", 'Avg Meteor Precision': 34.428875275993775, 'Avg Meteor Recall': 26.038735917738688, 'Avg Meteor F1': 29.1109748024941}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nOptions Rel: corenlp", 'Avg Meteor Precision': 36.553182202249985, 'Avg Meteor Recall': 24.317201723566995, 'Avg Meteor F1': 28.567748532576317}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: chat-gpt\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: rebel\nLocal RM: False\nRebel Model: Babelscape/rebel-large", 'Avg Meteor Precision': 31.58296475097177, 'Avg Meteor Recall': 26.687310902019398, 'Avg Meteor F1': 28.335923876355835}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: word2vec\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 36.08020429696237, 'Avg Meteor Recall': 24.47339883151345, 'Avg Meteor F1': 28.316822520780637}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nRanking Method: page_rank\nRanking Perc Threshold: 0.3\nOptions Rel: corenlp", 'Avg Meteor Precision': 35.160163467996824, 'Avg Meteor Recall': 24.686417740945043, 'Avg Meteor F1': 27.944736606625828}, {'Params': "Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}\nSummary Method: lex-rank\nSummary Percentage: 30\nOptions Rel: corenlp", 'Avg Meteor Precision': 44.00871387265893, 'Avg Meteor Recall': 20.92481679003488, 'Avg Meteor F1': 27.78972658652946}]
# Top 10 Avg Meteor Precision:
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Ranking Method: page_rank
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# Precision: 44.27574684680341
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: lex-rank
# Summary Percentage: 30
# Options Rel: corenlp
# Precision: 44.00871387265893
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# Precision: 43.65769014094927
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: lex-rank
# Summary Percentage: 30
# Options Rel: rebel
# Local RM: False
# Rebel Model: Babelscape/rebel-large
# Precision: 38.70915468350132
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Ranking Method: page_rank
# Ranking Perc Threshold: 0.3
# Options Rel: rebel
# Local RM: False
# Rebel Model: Babelscape/rebel-large
# Precision: 38.98260935237256
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: lex-rank
# Summary Percentage: 30
# Options Rel: rebel
# Local RM: True
# Rebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth
# Precision: 38.93965267196027
#
# Top 10 Avg Meteor Recall:
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 30
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.15
# Options Rel: corenlp
# Recall: 34.50135528761688
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 15
# Ranking Method: page_rank
# Ranking Perc Threshold: 0.15
# Options Rel: rebel
# Local RM: True
# Rebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth
# Recall: 31.050638651634646
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 30
# Ranking Method: page_rank
# Ranking Perc Threshold: 0.15
# Options Rel: corenlp
# Recall: 31.000162336682557
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 30
# Ranking Method: page_rank
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# Recall: 30.989374006799213
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 15
# Ranking Method: page_rank
# Ranking Perc Threshold: 0.15
# Options Rel: corenlp
# Recall: 30.875366506026484
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 15
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# Recall: 30.340468363524383
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 30
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# Recall: 30.310427790971186
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 15
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.15
# Options Rel: rebel
# Local RM: False
# Rebel Model: Babelscape/rebel-large
# Recall: 28.78794499253745
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 15
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.15
# Options Rel: rebel
# Local RM: True
# Rebel Model: ./src/fine_tune_rebel/finetuned_rebel.pth
# Recall: 28.719132894017253
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 15
# Ranking Method: page_rank
# Ranking Perc Threshold: 0.15
# Options Rel: rebel
# Local RM: False
# Rebel Model: Babelscape/rebel-large
# Recall: 28.551810280783368
#
# Top 10 Avg Meteor F1:
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 30
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# F1: 30.671572676698773
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 30
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.15
# Options Rel: corenlp
# F1: 30.133427099784356
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 15
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# F1: 29.640729305577235
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 30
# Ranking Method: page_rank
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# F1: 29.37900293325788
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 15
# Options Rel: corenlp
# F1: 29.1109748024941
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 30
# Options Rel: corenlp
# F1: 28.567748532576317
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: chat-gpt
# Summary Percentage: 30
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.3
# Options Rel: rebel
# Local RM: False
# Rebel Model: Babelscape/rebel-large
# F1: 28.335923876355835
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: lex-rank
# Summary Percentage: 30
# Ranking Method: word2vec
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# F1: 28.316822520780637
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: lex-rank
# Summary Percentage: 30
# Ranking Method: page_rank
# Ranking Perc Threshold: 0.3
# Options Rel: corenlp
# F1: 27.944736606625828
#
# Params: Preprocess: {'preprocess': True, 'spacy_model': 'en_core_web_lg'}
# Summary Method: lex-rank
# Summary Percentage: 30
# Options Rel: corenlp
# F1: 27.78972658652946

# %%
plotter.plot_top_metrics()
