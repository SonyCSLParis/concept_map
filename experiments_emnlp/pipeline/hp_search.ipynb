# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr, kendalltau

# %%
df = pd.read_csv("hp_search_results.csv", index_col=0).fillna("none")

params = [x for x in df.columns if not any(x.startswith(y) for y in ["rouge", "meteor"])]
metrics = [x for x in df.columns if any(x.startswith(y) for y in ["rouge", "meteor"])]
for p in params:
    print(f"{p}\t{df[p].unique()}")
df.head(3)
# Out:
# summary_method	['none' 'chat-gpt' 'lex-rank']
# summary_percentage	['none' 15.0 30.0]
# ranking	['page\\_rank' 'word2vec' 'none']
# ranking_how	['all' 'none']
# ranking_perc_threshold	[15.0 30.0 'none']
# entity	['dbpedia\\_spotlight' 'nps']
# relation	['corenlp' 'rebel\\_hf' 'rebel\\_ft']
#     summary_method summary_percentage     ranking ranking_how  \
# 15            none               none  page\_rank         all
# 116           none               none  page\_rank         all
# 129           none               none  page\_rank         all
#
#     ranking_perc_threshold              entity   relation  meteor_pr  \
# 15                    15.0  dbpedia\_spotlight    corenlp       37.0
# 116                   15.0  dbpedia\_spotlight  rebel\_hf       35.3
# 129                   15.0  dbpedia\_spotlight  rebel\_ft       33.0
#
#      meteor_re  meteor_f1  rouge-2_pr  rouge-2_re  rouge-2_f1
# 15        21.2       26.2         1.8        23.6         3.0
# 116       20.4       25.4         2.1        23.7         3.8
# 129       21.4       25.4         3.6        21.6         6.0

# %%
method_to_func = {"pearson": pearsonr, "kendall": kendalltau, "spearman": spearmanr}

def build_cols(metrics):
    """ Columns for df """
    columns = []
    for x in metrics:
        columns += [f"{x}_corr", f"{x}_pval"]
    return columns

def get_correlations(df, method, params, metrics):
    """ Retrieve correlations between params and metrics """
    data, mappings = [], {}
    for p in params:
        curr_data = []
        for m in metrics:
            if all (isinstance(x, float) for x in df[p].values):
                x = list(df[p].values)
            else:
                curr_mapping = {val: index for index, val in enumerate(df[p].unique())}
                mappings[p] = curr_mapping
                x = [curr_mapping[elt] for elt in df[p].values]
            curr_data += list(method_to_func[method](x, list(df[m].values)))
        data.append(curr_data)
    return pd.DataFrame(data, columns=build_cols(metrics), index=params), mappings

# %%
corrs, mappings = get_correlations(df[(df.summary_method != "none") & (df.ranking != 'none')], 'pearson', params, metrics)
for k, v in mappings.items():
    print(f"{k}:\t{v}")
corrs
# Out:
# summary_method:	{'chat-gpt': 0, 'lex-rank': 1}
# ranking:	{'page\\_rank': 0, 'word2vec': 1}
# ranking_how:	{'all': 0}
# entity:	{'dbpedia\\_spotlight': 0, 'nps': 1}
# relation:	{'rebel\\_ft': 0, 'corenlp': 1, 'rebel\\_hf': 2}
# /Users/ines/miniforge3/envs/ConceptMapsSummaries/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
#                         meteor_pr_corr  meteor_pr_pval  meteor_re_corr  \
# summary_method                0.270497    7.687618e-03       -0.370778
# summary_percentage            0.314392    1.811288e-03       -0.000757
# ranking                      -0.001280    9.901229e-01       -0.139073
# ranking_how                        NaN             NaN             NaN
# ranking_perc_threshold        0.493992    3.142141e-07       -0.021454
# entity                       -0.629332    6.538059e-12       -0.620655
# relation                      0.240124    1.844839e-02        0.025348
#
#                         meteor_re_pval  meteor_f1_corr  meteor_f1_pval  \
# summary_method            2.002158e-04       -0.006495    9.499242e-01
# summary_percentage        9.941580e-01        0.207331    4.267358e-02
# ranking                   1.765798e-01       -0.071941    4.860856e-01
# ranking_how                        NaN             NaN             NaN
# ranking_perc_threshold    8.356374e-01        0.327733    1.115824e-03
# entity                    1.529271e-11       -0.742395    4.883483e-18
# relation                  8.063411e-01        0.169795    9.815115e-02
#
#                         rouge-2_pr_corr  rouge-2_pr_pval  rouge-2_re_corr  \
# summary_method                -0.380048         0.000134         0.309673
# summary_percentage            -0.227694         0.025674         0.339991
# ranking                       -0.097942         0.342445        -0.012993
# ranking_how                         NaN              NaN              NaN
# ranking_perc_threshold        -0.322287         0.001363         0.479452
# entity                        -0.128915         0.210647        -0.570838
# relation                      -0.312700         0.001923         0.279812
#
#                         rouge-2_re_pval  rouge-2_f1_corr  rouge-2_f1_pval
# summary_method             2.138682e-03        -0.214963         0.035443
# summary_percentage         7.011391e-04        -0.072934         0.480074
# ranking                    9.000127e-01        -0.094046         0.362078
# ranking_how                         NaN              NaN              NaN
# ranking_perc_threshold     7.723788e-07        -0.000960         0.992596
# entity                     1.259399e-09        -0.414571         0.000027
# relation                   5.761575e-03        -0.096965         0.347304

# %%
df.groupby("relation").agg({x: "mean" for x in metrics})
# Out:
#            meteor_pr  meteor_re  meteor_f1  rouge-2_pr  rouge-2_re  rouge-2_f1
# relation
# corenlp    28.019565  20.958696  22.382609    2.745652   15.345652    3.223913
# rebel\_ft  26.025000  22.452083  22.877083    6.202083   14.368750    6.745833
# rebel\_hf  28.816667  22.158333  23.785417    4.468750   17.268750    5.735417

# %% [markdown]
# ## When both summarisation + ranking
# - `summary_method`: conflicting results for precision and recall. lex-rank correlates with higher precision, chat-gpt correlates with higher recall. f1 correlation for meteor null, chat-gpt better for rouge2-f1.
# - `summary_percentage`: 30 better for meteor precision+f1, recall rouge, 15 better for recall rouge
# - `ranking`: no real difference for meteor nor rouge
# - `ranking_how`: not applicable, only `single` for now
# - `ranking_perc_threshold`: 30 better for meteor precision+f1, rouge recall, 15 better for rouge precision
# - `entity`: dbpedia better for meteor precision+recall+f1, rouge recall+f1
# - `relation`: rebel_hf better for meteor recall+f1, rebel_ft better for rouge precision

# %%
corrs, mappings = get_correlations(df[df.summary_method == "none"], 'pearson', params, metrics)
for k, v in mappings.items():
    print(f"{k}:\t{v}")
corrs
# Out:
# summary_method:	{'none': 0}
# summary_percentage:	{'none': 0}
# ranking:	{'page\\_rank': 0, 'word2vec': 1}
# ranking_how:	{'all': 0}
# entity:	{'dbpedia\\_spotlight': 0, 'nps': 1}
# relation:	{'corenlp': 0, 'rebel\\_hf': 1, 'rebel\\_ft': 2}
# /Users/ines/miniforge3/envs/ConceptMapsSummaries/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
#                         meteor_pr_corr  meteor_pr_pval  meteor_re_corr  \
# summary_method                     NaN             NaN             NaN
# summary_percentage                 NaN             NaN             NaN
# ranking                       0.076438        0.735293       -0.536633
# ranking_how                        NaN             NaN             NaN
# ranking_perc_threshold        0.731257        0.000110       -0.124569
# entity                       -0.172542        0.442582       -0.366054
# relation                     -0.451431        0.034952        0.514555
#
#                         meteor_re_pval  meteor_f1_corr  meteor_f1_pval  \
# summary_method                     NaN             NaN             NaN
# summary_percentage                 NaN             NaN             NaN
# ranking                       0.010028       -0.502620        0.017124
# ranking_how                        NaN             NaN             NaN
# ranking_perc_threshold        0.580721        0.220339        0.324460
# entity                        0.093845       -0.453173        0.034170
# relation                      0.014278        0.346920        0.113695
#
#                         rouge-2_pr_corr  rouge-2_pr_pval  rouge-2_re_corr  \
# summary_method                      NaN              NaN              NaN
# summary_percentage                  NaN              NaN              NaN
# ranking                       -0.238535         0.285048         0.016149
# ranking_how                         NaN              NaN              NaN
# ranking_perc_threshold        -0.358692         0.101153         0.828140
# entity                        -0.063375         0.779334        -0.072551
# relation                       0.813643         0.000004        -0.315785
#
#                         rouge-2_re_pval  rouge-2_f1_corr  rouge-2_f1_pval
# summary_method                      NaN              NaN              NaN
# summary_percentage                  NaN              NaN              NaN
# ranking                        0.943136        -0.257574     2.471632e-01
# ranking_how                         NaN              NaN              NaN
# ranking_perc_threshold         0.000002        -0.325387     1.394957e-01
# entity                         0.748322        -0.081152     7.195875e-01
# relation                       0.152246         0.846022     7.047395e-07

# %% [markdown]
# ## When only ranking
# - `ranking`: page_rank best for meteor recall+f1, rouge f1
# - `ranking_how`: not applicable, only `single` for now
# - `ranking_perc_threshold`: 15 best for meteor precision, rouge f1, 30 best for rouge recall
# - `entity`: dbpedia better for meteor precision+recall+f1
# - `relation`: corenlp better for meteor precision, rebel_ft better for meteor recall, rouge precision+f1

# %%
corrs, mappings = get_correlations(df[df.ranking == "none"], 'pearson', params, metrics)
for k, v in mappings.items():
    print(f"{k}:\t{v}")
corrs
# Out:
# summary_method:	{'chat-gpt': 0, 'lex-rank': 1}
# ranking:	{'none': 0}
# ranking_how:	{'none': 0}
# ranking_perc_threshold:	{'none': 0}
# entity:	{'dbpedia\\_spotlight': 0, 'nps': 1}
# relation:	{'rebel\\_hf': 0, 'rebel\\_ft': 1, 'corenlp': 2}
# /Users/ines/miniforge3/envs/ConceptMapsSummaries/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4424: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
#                         meteor_pr_corr  meteor_pr_pval  meteor_re_corr  \
# summary_method                0.553891        0.004982       -0.439453
# summary_percentage            0.547782        0.005590       -0.052385
# ranking                            NaN             NaN             NaN
# ranking_how                        NaN             NaN             NaN
# ranking_perc_threshold             NaN             NaN             NaN
# entity                       -0.346182        0.097500       -0.605340
# relation                      0.078562        0.715192       -0.087327
#
#                         meteor_re_pval  meteor_f1_corr  meteor_f1_pval  \
# summary_method                0.031664       -0.154276        0.471665
# summary_percentage            0.807928        0.178010        0.405301
# ranking                            NaN             NaN             NaN
# ranking_how                        NaN             NaN             NaN
# ranking_perc_threshold             NaN             NaN             NaN
# entity                        0.001723       -0.717127        0.000080
# relation                      0.684926       -0.062291        0.772466
#
#                         rouge-2_pr_corr  rouge-2_pr_pval  rouge-2_re_corr  \
# summary_method                -0.441781         0.030669         0.557192
# summary_percentage            -0.334682         0.109917         0.555473
# ranking                             NaN              NaN              NaN
# ranking_how                         NaN              NaN              NaN
# ranking_perc_threshold              NaN              NaN              NaN
# entity                        -0.040162         0.852191        -0.237323
# relation                      -0.250039         0.238646        -0.031593
#
#                         rouge-2_re_pval  rouge-2_f1_corr  rouge-2_f1_pval
# summary_method                 0.004677        -0.434902         0.033683
# summary_percentage             0.004834        -0.308640         0.142265
# ranking                             NaN              NaN              NaN
# ranking_how                         NaN              NaN              NaN
# ranking_perc_threshold              NaN              NaN              NaN
# entity                         0.264157        -0.074822         0.728238
# relation                       0.883488        -0.312141         0.137562

# %% [markdown]
# ## When only summarising
# - `summary_method`: chat-gpt better for meteor+rouge precision, rouge f1, lex-rank better for meteor+rouge recall
# - `summary_percentage`: 30 better for meteor precision, rouge recall
# - `entity`: dbpedia better for meteor recall+f1
# - `relation`: no strong results

# %%
for p in params:
    print(df.groupby(p).agg({x: "mean" for x in metrics}))
# Out:
#                 meteor_pr  meteor_re  meteor_f1  rouge-2_pr  rouge-2_re  \
# summary_method
# chat-gpt        24.428333  23.983333  23.001667    5.841667   12.251667
# lex-rank        27.800000  21.031667  22.806667    4.108333   15.715000
# none            35.800000  18.386364  23.677273    1.886364   24.840909
#
#                 rouge-2_f1
# summary_method
# chat-gpt          6.150000
# lex-rank          5.093333
# none              3.309091
#                     meteor_pr  meteor_re  meteor_f1  rouge-2_pr  rouge-2_re  \
# summary_percentage
# 15.0                24.233333  22.540000  22.125000    5.511667   12.136667
# 30.0                27.995000  22.475000  23.683333    4.438333   15.830000
# none                35.800000  18.386364  23.677273    1.886364   24.840909
#
#                     rouge-2_f1
# summary_percentage
# 15.0                  5.858333
# 30.0                  5.385000
# none                  3.309091
#             meteor_pr  meteor_re  meteor_f1  rouge-2_pr  rouge-2_re  \
# ranking
# none        35.058333  20.258333  24.970833    2.458333   23.225000
# page\_rank  25.887931  22.950000  23.036207    5.206897   13.981034
# word2vec    26.306667  21.468333  22.233333    4.625000   14.270000
#
#             rouge-2_f1
# ranking
# none          4.133333
# page\_rank    5.770690
# word2vec      5.225000
#              meteor_pr  meteor_re  meteor_f1  rouge-2_pr  rouge-2_re  \
# ranking_how
# all          26.100847  22.196610  22.627966    4.911017   14.127966
# none         35.058333  20.258333  24.970833    2.458333   23.225000
#
#              rouge-2_f1
# ranking_how
# all            5.493220
# none           4.133333
#                         meteor_pr  meteor_re  meteor_f1  rouge-2_pr  \
# ranking_perc_threshold
# 15.0                    23.533333  22.251667  21.476667    5.563333
# 30.0                    28.756897  22.139655  23.818966    4.236207
# none                    35.058333  20.258333  24.970833    2.458333
#
#                         rouge-2_re  rouge-2_f1
# ranking_perc_threshold
# 15.0                     11.770000    5.545000
# 30.0                     16.567241    5.439655
# none                     23.225000    4.133333
#                     meteor_pr  meteor_re  meteor_f1  rouge-2_pr  rouge-2_re  \
# entity
# dbpedia\_spotlight  30.373239  24.012676  25.546479    4.730986   17.767606
# nps                 24.856338  19.725352  20.501408    4.261972   13.563380
#
#                     rouge-2_f1
# entity
# dbpedia\_spotlight    5.912676
# nps                   4.614085
#            meteor_pr  meteor_re  meteor_f1  rouge-2_pr  rouge-2_re  rouge-2_f1
# relation
# corenlp    28.019565  20.958696  22.382609    2.745652   15.345652    3.223913
# rebel\_ft  26.025000  22.452083  22.877083    6.202083   14.368750    6.745833
# rebel\_hf  28.816667  22.158333  23.785417    4.468750   17.268750    5.735417
